# %%
# Example 1 in Lecture 6

from CH02_quiver import eigen, direction_field, stream_lin

eigen( [[1,1] , [4,-2]], print_values=True)
direction_field(1,1,4,-2, xmin=-100, xmax=100, ymin=-100, ymax=100)
stream_lin(1,1,4,-2, xmin=-100, xmax=100, ymin=-100, ymax=100, density=1)
# Out:
# Eigenvalue 1 = 2.0, eigenvector 1 = [0.70710678 0.70710678], eigenvector 1 in nicer format = [1. 1.]
#
# Eigenvalue 2 = -3.0, eigenvector 2 = [-0.24253563  0.9701425 ], eigenvector 2 in nicer format = [ 1. -4.]

# %%
# Example 2 in Lecture 6

from CH02_quiver import eigen, direction_field

eigen( [[3,-4] , [1,-1]], print_values=True)
direction_field(3, -4, 1, -1, xmin=-100, xmax=100, ymin=-100, ymax=100, num_arrows=15)
stream_lin(3, -4, 1, -1, xmin=-100, xmax=100, ymin=-100, ymax=100, density=1)
# Out:
# Eigenvalue 1 = 1.0, eigenvector 1 = [0.89442719 0.4472136 ], eigenvector 1 in nicer format = [2. 1.]
#
# Eigenvalue 2 = 1.0, eigenvector 2 = [0.89442719 0.4472136 ], eigenvector 2 in nicer format = [2. 1.]
