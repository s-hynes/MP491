# %% [markdown]
# ### 2024 Q.1.e.
# $$x_{n+1} = x_n (x_n - 2)$$

# %%
from CH05_1d_maps import conv
conv(3, 0.5, 500, lambda r,x: x*(x-2))
conv(2.9, 0.5, 500, lambda r,x: x*(x-2))
# Out:
# For r = 0.50
#
# xₒ=3.0 is a fixed point so the map "converges" after 0 iterations to 3.0.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %%
from CH05_1d_maps import conv
conv(0, 0.5, 500, lambda r,x: x*(x-2))
conv(0.1, 0.5, 500, lambda r,x: x*(x-2))
# Out:
# For r = 0.50
#
# xₒ=0.0 is a fixed point so the map "converges" after 0 iterations to 0.0.
# No percentage difference calculated because the denominator is zero.
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %% [markdown]
# ### 2023 Q.1.e. (identical to 2024)
# $$x_{n+1} = x_n (x_n - 2)$$

# %% [markdown]
# ### 2022 Q.1.e.
# $$x_{n+1} = \frac{x_n}{2} (3 - x_n^2)$$

# %%
from CH05_1d_maps import conv
conv(0, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
conv(0.01, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
conv(-0.01, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
# Out:
# For r = 0.50
#
# xₒ=0.0 is a fixed point so the map "converges" after 0 iterations to 0.0.
# No percentage difference calculated because the denominator is zero.
# For r = 0.50
#
# xₙ converges after 15 iterations to 1.0.
# Percentage difference from previous iteration = 0.000024%
# For r = 0.50
#
# xₙ converges after 15 iterations to -1.0.
# Percentage difference from previous iteration = 0.000024%

# %%
from CH05_1d_maps import conv
conv(2.2, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
conv(1.5, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
# Out:
# For r = 0.50
#
# xₙ converges after 5 iterations to 1.0.
# Percentage difference from previous iteration = 0.000041%
# For r = 0.50
#
# xₙ converges after 6 iterations to 1.0.
# Percentage difference from previous iteration = 0.000003%

# %%
from CH05_1d_maps import conv
conv(1, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
conv(-1, 0.5, 500, lambda r,x: (x/2)*(3-x**2))
# Out:
# For r = 0.50
#
# xₒ=1.0 is a fixed point so the map "converges" after 0 iterations to 1.0.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# xₒ=-1.0 is a fixed point so the map "converges" after 0 iterations to -1.0.
# Percentage difference from previous iteration = 0.000000%

# %% [markdown]
# ### <mark>No Exam Papers for 2021 and 2020</mark>

# %% [markdown]
# ### 2019 Q.1.d.
# $$x_{n+1} = 4 x_n (1 - x_n)$$

# %%
from CH05_1d_maps import conv
conv(0, 0.5, 500, lambda r,x: 4*x*(1-x))
conv(0.01, 0.5, 500, lambda r,x: 4*x*(1-x))
# Out:
# For r = 0.50
#
# xₒ=0.0 is a fixed point so the map "converges" after 0 iterations to 0.0.
# No percentage difference calculated because the denominator is zero.
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %%
from CH05_1d_maps import conv
conv(3/4, 0.5, 500, lambda r,x: 4*x*(1-x))
conv(3/4 + 0.01, 0.5, 500, lambda r,x: 4*x*(1-x))
# Out:
# For r = 0.50
#
# xₒ=0.75 is a fixed point so the map "converges" after 0 iterations to 0.75.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %% [markdown]
# ### 2018 Q.1.d.
# $$x_{n+1} = 2 (x_n)^2 + 11 x_n + 12$$

# %%
from CH05_1d_maps import conv, mapping
conv(-3, 0.5, 500, lambda r,x: 2*(x**2) + 11*x + 12)
conv(-3.1, 0.5, 500, lambda r,x: 2*(x**2) + 11*x + 12)

print(mapping(-3.1, 0.5, 1000000, lambda r,x: 2*(x**2) + 11*x + 12)[-20:])
conv(-3.1, 0.5, 1000000, lambda r,x: 2*(x**2) + 11*x + 12)
# Out:
# For r = 0.50
#
# xₒ=-3.0 is a fixed point so the map "converges" after 0 iterations to -3.0.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled
# [-2.99964632 -3.00035343 -2.99964632 -3.00035343 -2.99964632 -3.00035343
#  -2.99964632 -3.00035343 -2.99964632 -3.00035343 -2.99964632 -3.00035343
#  -2.99964632 -3.00035342 -2.99964633 -3.00035342 -2.99964633 -3.00035342
#  -2.99964633 -3.00035342]
#
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %%
from CH05_1d_maps import conv
conv(-2, 0.5, 500, lambda r,x: 2*(x**2) + 11*x + 12)
conv(-2.1, 0.5, 500, lambda r,x: 2*(x**2) + 11*x + 12)
# Out:
# For r = 0.50
#
# xₒ=-2.0 is a fixed point so the map "converges" after 0 iterations to -2.0.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %% [markdown]
# ### 2017 Q.1.d.
# $$x_{n+1} =3 x_n (1-x_n)$$

# %%
from CH05_1d_maps import conv
conv(0, 0.5, 500, lambda r,x: 3*x*(1-x))
conv(0.01, 0.5, 500, lambda r,x: 3*x*(1-x))
# Out:
# For r = 0.50
#
# xₒ=0.0 is a fixed point so the map "converges" after 0 iterations to 0.0.
# No percentage difference calculated because the denominator is zero.
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %%
from CH05_1d_maps import conv
conv(2/3, 0.5, 100, lambda r,x: 3*x*(1-x))

conv(2/3 + 0.001, 0.5, 100, lambda r,x: 3*x*(1-x))
print("Values at last 20 iterations:", mapping(2/3 + 0.001, 0.5, 100, lambda r,x: 3*x*(1-x))[-20:])

conv(2/3 + 0.001, 0.5, 1000000, lambda r,x: 3*x*(1-x))
print("Values at last 20 iterations:", mapping(2/3 + 0.001, 0.5, 1000000, lambda r,x: 3*x*(1-x))[-20:])
# Out:
# For r = 0.50
#
# xₙ converges after 1 iterations to 0.6667.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled
# Values at last 20 iterations: [0.66566439 0.66766593 0.66566441 0.66766591 0.66566443 0.66766589
#  0.66566445 0.66766587 0.66566446 0.66766586 0.66566448 0.66766584
#  0.6656645  0.66766582 0.66566452 0.6676658  0.66566454 0.66766578
#  0.66566455 0.66766577]
#
# For r = 0.50
#
# Does not converge for the number of iterations modelled
# Values at last 20 iterations: [0.66643715 0.66689602 0.66643715 0.66689602 0.66643715 0.66689602
#  0.66643715 0.66689602 0.66643715 0.66689602 0.66643715 0.66689602
#  0.66643715 0.66689602 0.66643715 0.66689602 0.66643715 0.66689602
#  0.66643715 0.66689602]

# %% [markdown]
# ### 2016 Q.1.d. (same as Problem Sheet 5 Q.5.)
# $$x_{n+1} = x_n (x_n - 1)(x_n + 1)$$

# %% [markdown]
# ### 2015 Q.1.d. (same as Problem Sheet 5 Q.1.)
# $$x_{n+1} = x_n (x_n - 1)(x_n + 1)$$

# %% [markdown]
# ### 2014 Q.1.d. (same as Problem Sheet 5 Q.3.)
# $$x_{n+1} = x_n (x_n - 1)(x_n + 1)$$

# %% [markdown]
# ### 2013 Q.1.d.
# $$x_{n+1} = x_n - (x_n)^2 + 4$$

# %%
from CH05_1d_maps import conv
import warnings

warnings.filterwarnings("ignore", ".*scalar.*")
conv(2, 0.5, 50, lambda r,x: x - x**2 + 4)
conv(2.01, 0.5, 50, lambda r,x: x - x**2 + 4)
# Out:
# For r = 0.50
#
# xₒ=2.0 is a fixed point so the map "converges" after 0 iterations to 2.0.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %%
from CH05_1d_maps import conv
import warnings

warnings.filterwarnings("ignore", ".*scalar.*")
conv(-2, 0.5, 50, lambda r,x: x - x**2 + 4)
conv(-1.99, 0.5, 50, lambda r,x: x - x**2 + 4)
# Out:
# For r = 0.50
#
# xₒ=-2.0 is a fixed point so the map "converges" after 0 iterations to -2.0.
# Percentage difference from previous iteration = 0.000000%
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %%
from CH05_1d_maps import conv
import warnings

warnings.filterwarnings("ignore", ".*scalar.*")
conv(1, 0.5, 50, lambda r,x: x - x**2 + 4)
# Out:
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %% [markdown]
# ### <mark>No short questions like this on 1D Maps 2012-2008 </mark>
