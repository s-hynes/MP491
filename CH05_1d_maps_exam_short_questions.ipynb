# %% [markdown]
# ### 2024 Q.1.e.
# $$x_{n+1} = x_n (x_n - 2)$$

# %%
from CH05_1d_maps import conv
conv(2.5, 0.5, 500, lambda r,x: x*(x-2))
# Out:
# For r = 0.50
#
# Does not converge for the number of iterations modelled

# %% [markdown]
# ### 2023 Q.1.e. (identical to 2024)
# $$x_{n+1} = x_n (x_n - 2)$$

# %% [markdown]
# ### 2022 Q.1.e.
# $$x_{n+1} = \frac{x_n}{2} (3 - x_n^2)$$

# %% [markdown]
# ### <mark>No Exam Papers for 2021 and 2020</mark>

# %% [markdown]
# ### 2019 Q.1.e.
# $$x_{n+1} = 4 x_n (1 - x_n)$$

# %% [markdown]
# ### 2018 Q.1.e.
# $$x_{n+1} = 2 (x_n)^2 + 11 x_n + 12$$

# %% [markdown]
# ### 2017 Q.1.e.
# $$x_{n+1} =3 x_n (1-x_n)$$

# %% [markdown]
# ### 2016 Q.1.e. (same as Problem Sheet 5 Q.5.)
# $$x_{n+1} = x_n (x_n - 1)(x_n + 1)$$

# %% [markdown]
# ### 2015 Q.1.e. (same as Problem Sheet 5 Q.1.)
# $$x_{n+1} = x_n (x_n - 1)(x_n + 1)$$

# %% [markdown]
# ### 2014 Q.1.e. (same as Problem Sheet 5 Q.3.)
# $$x_{n+1} = x_n (x_n - 1)(x_n + 1)$$

# %% [markdown]
# ### 2013 Q.1.e.
# $$x_{n+1} = x_n - (x_n)^2 + 4$$

# %% [markdown]
# ### <mark>No short questions like this on 1D Maps 2012-2008 </mark>
