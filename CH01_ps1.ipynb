# %% [markdown]
# #### **Q1.** $\frac{dx}{dt} = a x + 3 x^2$

# %%
from CH01_bifurcation import plotter
plotter((lambda r: (lambda x: r*x + 3*(x**2))), fstring="r*x + 3*(x**2)", rmin=-5, rmax=5, rstep=0.01)
# Out:
# Number of points that stability function thinks aren't roots = 9

# %% [markdown]
# #### **Q2.** $ \frac{dx}{dt} = a x + 2 x^3$

# %%
from CH01_bifurcation import plotter
plotter((lambda r: (lambda x: r*x + 2*(x**3))), fstring="r*x + 2*(x**3)", rmin=-5, rmax=5, rstep=0.01)
# Out:
# Number of points that stability function thinks aren't roots = 36

# %% [markdown]
# #### **Q3.** $ \frac{dx}{dt} = a + x^2$

# %%
from CH01_bifurcation import plotter
plotter((lambda r: (lambda x: r + x**2)), fstring="r + x**2", rmin=-5, rmax=5, rstep=0.01)
# Out:
# Number of points that stability function thinks aren't roots = 766

# %% [markdown]
# #### **Q4.** $ \frac{dx}{dt} = a x - 4 x^3 $

# %%
from CH01_bifurcation import plotter
plotter((lambda r: (lambda x: r*x - 4*(x**3) )), fstring="r*x - 4*(x**3)", rmin=-5, rmax=5, rstep=0.01)
# Out:
# Number of points that stability function thinks aren't roots = 30

# %% [markdown]
# #### **Q5.** $ \frac{dx}{dt} = 1 - a x^2$

# %%
from CH01_bifurcation import plotter
plotter((lambda r: (lambda x: 1 - r*(x**2) )), fstring="1 - r*(x**2)", rmin=0.1, rmax=5, rstep=0.01)
# Out:
# Number of points that stability function thinks aren't roots = 33
