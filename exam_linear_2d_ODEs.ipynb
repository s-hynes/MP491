# %% [markdown]
# ### 2024 Q1.b.
#
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 5 & 2 \\ -17 & -5 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[5,2], [-17, -5]], print_values=True)
direction_field(5,2,-17,-5, num_arrows=21)
# Out:
# Eigenvalue 1 = (-3.885780586188048e-16+2.9999999999999996j), eigenvector 1 = [-0.27820744-0.16692447j  0.9459053 +0.j        ], eigenvector 1 in nicer format = [ 1. -0.j  -2.5+1.5j]
#
# Eigenvalue 2 = (-3.885780586188048e-16-2.9999999999999996j), eigenvector 2 = [-0.27820744+0.16692447j  0.9459053 -0.j        ], eigenvector 2 in nicer format = [ 1. -0.j  -2.5-1.5j]
# c:\Users\Stephen\Documents\Coding\24-25_Sem_2_Coding\MP491\quiver.py:72: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# ### 2023 Q1.b.
#
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} -2 & 1 \\ 1 & -2 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[-2,1], [1, -2]], print_values=True)
direction_field(-2,1,1,-2, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=21)
# Out:
# Eigenvalue 1 = -1.0, eigenvector 1 = [0.70710678 0.70710678], eigenvector 1 in nicer format = [1. 1.]
#
# Eigenvalue 2 = -3.0, eigenvector 2 = [-0.70710678  0.70710678], eigenvector 2 in nicer format = [ 1. -1.]

# %% [markdown]
# ### 2022 Q1.b.
#
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 1 & 1 \\ 4 & -2 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[ 1, 1], [ 4, -2]], print_values=True)
direction_field( 1, 1, 4, -2, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = 2.0, eigenvector 1 = [0.70710678 0.70710678], eigenvector 1 in nicer format = [1. 1.]
#
# Eigenvalue 2 = -3.0, eigenvector 2 = [-0.24253563  0.9701425 ], eigenvector 2 in nicer format = [ 1. -4.]

# %% [markdown]
# ### 2019 Q1.b.
# $$\begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 1 & -2 \\ 1 & -1 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}$$

# %%
from quiver import eigen, direction_field
eigen([[ 1, -2], [ 1, -1]], print_values=True)
direction_field( 1, -2, 1, -1, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = (9.71445146547012e-17+0.9999999999999998j), eigenvector 1 = [0.81649658+0.j         0.40824829-0.40824829j], eigenvector 1 in nicer format = [1.+1.j 1.+0.j]
#
# Eigenvalue 2 = (9.71445146547012e-17-0.9999999999999998j), eigenvector 2 = [0.81649658-0.j         0.40824829+0.40824829j], eigenvector 2 in nicer format = [1.-1.j 1.+0.j]

# %% [markdown]
# ### 2018 Q1.b. (Same as 2023 Q1.b.)
# $$\begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} -2 & 1 \\ 1 & -2 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}$$

# %% [markdown]
# ### 2017 Q1.b.
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 3 & -3 \\ 4 & -3 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[ 3, -3], [ 4, -3]], print_values=True)
direction_field( 3, -3, 4, -3, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = (-1.1102230246251565e-16+1.7320508075688774j), eigenvector 1 = [0.56694671+0.32732684j 0.75592895+0.j        ], eigenvector 1 in nicer format = [1.+0.j         1.-0.57735027j]
#
# Eigenvalue 2 = (-1.1102230246251565e-16-1.7320508075688774j), eigenvector 2 = [0.56694671-0.32732684j 0.75592895-0.j        ], eigenvector 2 in nicer format = [1.+0.j         1.+0.57735027j]

# %% [markdown]
# ### 2016 Q1.b.
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 5 & -2 \\ 4 & -1 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[ 5, -2], [ 4, -1]], print_values=True)
direction_field( 5, -2, 4, -1, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = 3.0, eigenvector 1 = [0.70710678 0.70710678], eigenvector 1 in nicer format = [1. 1.]
#
# Eigenvalue 2 = 1.0, eigenvector 2 = [0.4472136  0.89442719], eigenvector 2 in nicer format = [1. 2.]

# %% [markdown]
# ### 2015 Q1.b.
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 1 & 3 \\ 1 & -1 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[ 1, 3], [ 1, -1]], print_values=True)
direction_field( 1, 3, 1, -1, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = 2.0, eigenvector 1 = [0.9486833  0.31622777], eigenvector 1 in nicer format = [3. 1.]
#
# Eigenvalue 2 = -2.0, eigenvector 2 = [-0.70710678  0.70710678], eigenvector 2 in nicer format = [ 1. -1.]

# %% [markdown]
# ### 2014 Q1.b.
# $$
# \begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 2 & 3 \\ -1 & 1 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}
# $$

# %%
from quiver import eigen, direction_field
eigen([[ 2, 3], [ -1, 1]], print_values=True)
direction_field( 2, 3, -1, 1, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = (1.5+1.6583123951776997j), eigenvector 1 = [ 0.8660254 +0.j         -0.14433757+0.47871355j], eigenvector 1 in nicer format = [-0.5-1.6583124j  1. +0.j       ]
#
# Eigenvalue 2 = (1.5-1.6583123951776997j), eigenvector 2 = [ 0.8660254 -0.j         -0.14433757-0.47871355j], eigenvector 2 in nicer format = [-0.5+1.6583124j  1. -0.j       ]

# %% [markdown]
# ### 2013 Q1.b.
# $$\begin{equation*}
# \begin{pmatrix} \dot x \\ \dot y \end{pmatrix} = \begin{pmatrix} 1 & 3 \\ -2 & 3 \end{pmatrix} \begin{pmatrix} x \\ y \end{pmatrix}
# \end{equation*}$$

# %%
from quiver import eigen, direction_field
eigen([[ 1, 3], [ -2, 3]], print_values=True)
direction_field( 1, 3, -2, 3, xmin=-20, xmax=20, ymin=-20, ymax=20, num_arrows=25)
# Out:
# Eigenvalue 1 = (2+2.23606797749979j), eigenvector 1 = [0.77459667+0.j         0.25819889+0.57735027j], eigenvector 1 in nicer format = [0.5-1.11803399j 1. +0.j        ]
#
# Eigenvalue 2 = (2-2.23606797749979j), eigenvector 2 = [0.77459667-0.j         0.25819889-0.57735027j], eigenvector 2 in nicer format = [0.5+1.11803399j 1. -0.j        ]

# %% [markdown]
# ### 2012
#
# Question 1 being compulsory short questions covering each chapter of the course only began in 2013.
