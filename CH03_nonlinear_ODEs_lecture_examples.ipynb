# %% [markdown]
# ## Lecture 14 Example 1
#
# $$
# \begin{align*}
#     \dot x &= y \\
#     \dot y &= x^3 - x
# \end{align*}
# $$
#
# 1. Check whether the system is Hamiltonian.
# 2. Find the Hamiltonian function.
# 3. Sketch the corresponding phase portrait of the nonlinear system (using level curves).
#
# The code will do part 3.

# %%
from CH03_nonlinear import direction_field2, stream
stream(xdot=lambda x,y: y, ydot=lambda x,y: x**3 - x, xmin=-3, xmax=3, ymin=-3, ymax=3, eq_pts=[ [-1,0], [0,0], [1,0]], density=[1, 1])

# %% [markdown]
# ## Lecture 15 Example 1
# $$
# \begin{align*}
#     \dot x &= y\left(13 - x^2 - y^2 \right) \\
#     \dot y &= 12 - x \left(13 - x^2 - y^2 \right)
# \end{align*}
# $$
#
# 1. Check whether the system is Hamiltonian.
# 2. Find the Hamiltonian function.
# 3. Sketch the corresponding phase portrait of the nonlinear system (using level curves).
#
# The code will do part 3. It's also worth noting that this a ridiculous example question and nothing this long-winded has ever been asked on an end of semester exam.

# %%
from CH03_nonlinear import direction_field2, stream
stream(xdot=lambda x,y: y*(13 - x**2 -y**2), ydot=lambda x,y: 12 - x*(13 - x**2 -y**2), xmin=-6, xmax=6, ymin=-6, ymax=6, eq_pts=[ [-4,0], [1,0], [3,0]], density=1.5)
stream(xdot=lambda x,y: y*(13 - x**2 -y**2), ydot=lambda x,y: 12 - x*(13 - x**2 -y**2), xmin=-50, xmax=50, ymin=-50, ymax=50, eq_pts=[ [-4,0], [1,0], [3,0]], density=1.5)
