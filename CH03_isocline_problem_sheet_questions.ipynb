# %% [markdown]
# ## Problem Sheet 3 Questions on Isoclines
#
# [Question 1](#q1)</br>
# [Question 2](#q2)

# %% [markdown]
# ### Q.1.
# $$
# \begin{align*}
#     \dot x &= -x - y \\
#     \dot y &= -x + y + 2xy
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: -x-y, lambda x,y: -x+y+2*x*y, xmin=-3, xmax=3, ymin=-3, ymax=3, eq_pts=[ [0,0], [-1,1]])

# %% [markdown]
# ### Q.2.
# $$
# \begin{align*}
#     \dot x &= x - y - 2xy \\
#     \dot y &= 4x + y
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: x-y-2*x*y, lambda x,y: 4*x+y, xmin=-4, xmax=4, ymin=-4, ymax=4, eq_pts=[ [0,0], [-5/8,5/2]])
