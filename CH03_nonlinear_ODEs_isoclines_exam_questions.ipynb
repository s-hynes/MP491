# %% [markdown]
# ### 2022 Q3.c.
# $$
# \begin{align*}
#     \dot x &= y^2 - x - 1 \\
#     \dot y &= y^2 + x - 1
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: y**2 - x - 1, lambda x,y: y**2 + x - 1, xmin=-4, xmax=4, ymin=-4, ymax=4, eq_pts=[ [0,1], [0,-1]])

# %% [markdown]
# ### 2018 Q3.c.
# $$
# \begin{align*}
#     \dot x &= xy - x + y - 1 \\
#     \dot y &= xy
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: x*y - x + y -1, lambda x,y: x*y, xmin=-4, xmax=4, ymin=-4, ymax=4, eq_pts=[ [-1,0], [0,1]])

# %% [markdown]
# ### 2016 Q3.c.
# $$
# \begin{align*}
#     \dot x &= 2xy \\
#     \dot y &= x^2 + y^2 - 1
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: 2*x*y, lambda x,y: x**2 + y**2 - 1, xmin=-3, xmax=3, ymin=-3, ymax=3, eq_pts=[ [1,0], [-1,0], [0,1], [0,-1]], density=1.2)

# %% [markdown]
# ### 2013 Q3.c.
# $$
# \begin{align*}
#     \dot x &= (x-2)(y+2)) \\
#     \dot y &= (x+1)(y-1)
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: (x-2)*(y+2), lambda x,y: (x+1)*(y-1), xmin=-3, xmax=4, ymin=-3, ymax=4, eq_pts=[ [-1,-2], [2,1]], density=1)

# %% [markdown]
# ### 2012 Q4.c.
# $$
# \begin{align*}
#     \dot x &= xy + 2x - y - 2 \\
#     \dot y &= xy - 3x +y - 3
# \end{align*}
# $$

# %%
from CH03_nonlinear import stream
stream(lambda x,y: x*y+2*x-y-2, lambda x,y: x*y-3*x+y-3, xmin=-4, xmax=4, ymin=-4, ymax=4, eq_pts=[ [1,3], [-1,-2]], density=1)
